# %%
# PANDA SERIES

# %% [markdown]
# PANDA SERIES

# %%
import pandas as pd
import numpy as np

# %%
# Series from Lists have index a

country=["Baladesh","India"]
pd.Series(country)
# Out:
# 0    Baladesh
# 1       India
# dtype: object

# %%
runs=[10,56,100]

pd.Series(runs)
# Out:
# 0     10
# 1     56
# 2    100
# dtype: int64

# %%
#costom index
marks=[67,67,135]
subjects=["English","Hindi","aths"]
pd.Series(marks,index=subjects)
# Out:
# English     67
# Hindi       67
# aths       135
# dtype: int64
